# %% [markdown]
# # Exercice 1  Traitement de Liste - Somme valeurs

# %% [markdown]
# 1 - Vous devez réaliser la fonction **sommeListe** qui prend en paramètre un liste **liste** et qui renvoi la somme des valeurs de la liste et 0 si la liste est vide.

# %%
def sommeListe(liste):
    pass # Enlever l'instruction pass et saisir votre code

# %% [markdown]
# 2 - Vérification :
# Ne pas modifier les lignes ci-dessous. Vous pouvez tester votre code en exécutant les tests ci-dessous.

# %%
assert sommeListe([1,1,2])==4,"Erreur cas 1"
assert sommeListe([-1,1])==0,"Erreur cas 2"
assert sommeListe([])==0,"Erreur si la liste est vide"

# %% [markdown]
# 3 - Vous pouvez ajouter les spécifications et asssertion :
#        - Descriptif général de la fonction
#        - type de paramètres
#        - Conditions sur les paramètres
#        - type de variable retournée
#        - Eventuellement : assertion sur les conditions des paramètres
